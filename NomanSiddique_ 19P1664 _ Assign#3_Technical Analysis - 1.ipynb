# %%
# Bismillah

# P19-1664 Noman Siddique

# Assignment # 3
# Technical Analysis on Three companies

# %%
import pandas_datareader.data as web
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()

# %%
start = dt.datetime(2020, 1, 1)
end = dt.datetime(2020, 9, 7)
# tickers = ['FB', 'INTC', 'ADBE'] 
tickers = ['FB', 'CVNA', 'JD']
cc = 'BTC-USD' # Bitcoin in USD

# %%
for ticker in tickers:
   data = web.DataReader(ticker, 'yahoo', start, end)
   data.to_csv('{}.csv'.format(ticker))

# %%
data = pd.read_csv('FB.csv', parse_dates = True, index_col = 'Date')
data
# Out:
#                    High          Low         Open        Close    Volume  \
# Date
# 2019-12-31  205.5599976  203.6000061  204.0000000  205.2500000   8953500
# 2020-01-02  209.7899933  206.2700043  206.7500000  209.7799988  12077100
# 2020-01-03  210.3999939  206.9499969  207.2100067  208.6699982  11188400
# 2020-01-06  212.7799988  206.5200043  206.6999969  212.6000061  17058900
# 2020-01-07  214.5800018  211.7500000  212.8200073  213.0599976  14912400
# ...                 ...          ...          ...          ...       ...
# 2020-08-31  296.8800049  291.5499878  293.9500122  293.2000122  17345100
# 2020-09-01  301.4899902  292.7099915  294.7099915  295.4400024  17295900
# 2020-09-02  303.6000061  293.0499878  298.8800049  302.5000000  24341400
# 2020-09-03  297.6000061  283.6300049  295.9899902  291.1199951  32294100
# 2020-09-04  289.0000000  271.1400146  287.2500000  282.7300110  30333700
#
#               Adj Close
# Date
# 2019-12-31  205.2500000
# 2020-01-02  209.7799988
# ...

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Facebook')
ax2 = plt.subplot2grid((7, 1), (4, 0), rowspan = 3, colspan = 1, sharex = ax1)

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Facebook')
ax2 = plt.subplot2grid((7, 1), (4, 0), rowspan = 3, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')
# Out:
# <BarContainer object of 173 artists>

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Facebook')
ax2 = plt.subplot2grid((7, 1), (4, 0), rowspan = 3, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')

ax1.legend()
ax2.legend(loc = 'upper right')
plt.show()

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Facebook')
ax2 = plt.subplot2grid((7, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')

ax1.legend()
ax2.legend(loc = 'upper right')
plt.show()

# %%
import matplotlib.dates as mdates

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Facebook - 2020')
ax2 = plt.subplot2grid((7, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
ax2.set_xlabel('Date (Month - Day)')

ax1.legend()
ax2.legend(loc = 'upper right')
plt.show()

# %%
from matplotlib import style
style.use('ggplot') # try 'ggplot and seaborn'

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = 'Facebook - 2020')
ax2 = plt.subplot2grid((7, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax2.bar(data.index, data['Volume'], label = 'Volume')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
ax2.set_xlabel('Date (Month - Day)')

ax1.legend()
ax2.legend(loc = 'upper right')
plt.savefig('Facebook-2020')
plt.show()

# %%
data['Adj Close']
# Out:
# Date
# 2019-12-31    205.2500000
# 2020-01-02    209.7799988
# 2020-01-03    208.6699982
# 2020-01-06    212.6000061
# 2020-01-07    213.0599976
#                  ...
# 2020-08-31    293.2000122
# 2020-09-01    295.4400024
# 2020-09-02    302.5000000
# 2020-09-03    291.1199951
# 2020-09-04    282.7300110
# Name: Adj Close, Length: 173, dtype: float64

# %%
3294.620117 / 1847.839966 # Almost 78 percent return in 09 months time.
# Out:
# 1.7829574950323377

# %% [markdown]
# ## Moving Average:

# %%
start = dt.datetime(2015, 1, 1)
end = dt.datetime(2020, 9, 7)
ticker = 'JD'

# %%
data = web.DataReader(ticker, 'yahoo', start, end)
data
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2014-12-31  23.4799995  22.8500004  23.2999992  23.1399994   5262600
# 2015-01-02  24.1100006  23.1499996  23.3700008  24.0200005   3358500
# 2015-01-05  24.9500008  24.0000000  24.0200005  24.5799999   5029600
# 2015-01-06  25.0100002  24.1499996  24.6000004  24.5300007   9797800
# 2015-01-07  25.0900002  24.5699997  24.8600006  24.8099995   9084400
# ...                ...         ...         ...         ...       ...
# 2020-08-31  80.4700012  78.5699997  79.9400024  78.6399994  12917300
# 2020-09-01  83.0000000  79.1449966  79.4899979  82.4899979  11431400
# 2020-09-02  86.5800018  81.8000031  85.4589996  83.2099991  13860900
# 2020-09-03  81.6900024  76.0299988  81.3750000  79.0400009  19254000
# 2020-09-04  80.8000031  75.4000015  77.9660034  80.0000000  21500900
#
#              Adj Close
# Date
# 2014-12-31  22.5705376
# 2015-01-02  23.4288826
# 2015-01-05  23.9751015
# 2015-01-06  23.9263325
# ...

# %%
data['SMA20'] = data['Adj Close'].rolling(20).mean()
data['SMA120'] = data['Adj Close'].rolling(120).mean()
data.head(30)

#
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2014-12-31  23.4799995  22.8500004  23.2999992  23.1399994   5262600
# 2015-01-02  24.1100006  23.1499996  23.3700008  24.0200005   3358500
# 2015-01-05  24.9500008  24.0000000  24.0200005  24.5799999   5029600
# 2015-01-06  25.0100002  24.1499996  24.6000004  24.5300007   9797800
# 2015-01-07  25.0900002  24.5699997  24.8600006  24.8099995   9084400
# 2015-01-08  25.2900009  24.5100002  24.8199997  25.0799999  12821700
# 2015-01-09  25.5550003  24.7500000  25.0100002  24.9400005   8119800
# 2015-01-12  24.8799992  23.8400002  24.8799992  24.1100006   4228600
# 2015-01-13  24.3299999  23.5900002  24.2700005  23.8400002   4772100
# 2015-01-14  24.2999992  23.5000000  23.6000004  23.8199997   3829500
# 2015-01-15  24.0300007  22.9599991  24.0200005  23.3199997   5076800
# 2015-01-16  24.1700001  23.0799999  23.1900005  24.0699997   6879100
# ...

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((7, 1), (0, 0), rowspan = 4, colspan = 1, title = ticker)
ax2 = plt.subplot2grid((7, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price', alpha = 0.75)
ax1.plot(data['SMA20'], label = 'SMA20')
ax1.plot(data['SMA120'], label = 'SMA120')

ax2.bar(data.index, data['Volume'], label = 'Volume')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y, %m'))

ax2.set_xlabel('Date (Year - Month)')

ax1.legend()
ax2.legend(loc = 'upper right')

# when SMA20 goes above SMA120, it signal to buy as it suggests that there is a recent surge in buying pressure, 
# that is, investors are willing to buy it more recently as compared to the long-term trend. By the same token, 
# SMA20 going below SMA120 suggests that the price is decreasing recently as compared to long-term trend so we 
# should sell it if we already hold it or maybe short sell it if we don't already own it. Explain short selling
# to the students.

# %%
data = data.drop(columns = ['High', 'Low', 'Open', 'Close']) # remove the unneeded columns.

# %%
data
# Out:
#               Volume   Adj Close       SMA20      SMA120
# Date
# 2014-12-31   5262600  22.5705376         NaN         NaN
# 2015-01-02   3358500  23.4288826         NaN         NaN
# 2015-01-05   5029600  23.9751015         NaN         NaN
# 2015-01-06   9797800  23.9263325         NaN         NaN
# 2015-01-07   9084400  24.1994400         NaN         NaN
# ...              ...         ...         ...         ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866
#
# [1431 rows x 4 columns]

# %%
data['price_yesterday'] = data['Adj Close'].shift(1)
data.head()

# the adj. close values have been shifted one day forward. Subtracting price_yesterday from adj. close in the same
# row gives absolute change. Dividing this absolute change by price_yesterday gives net percentage change.
# Out:
#              Volume   Adj Close  SMA20  SMA120  price_yesterday
# Date
# 2014-12-31  5262600  22.5705376    NaN     NaN              NaN
# 2015-01-02  3358500  23.4288826    NaN     NaN       22.5705376
# 2015-01-05  5029600  23.9751015    NaN     NaN       23.4288826
# 2015-01-06  9797800  23.9263325    NaN     NaN       23.9751015
# 2015-01-07  9084400  24.1994400    NaN     NaN       23.9263325

# %%
(24.714506 - 24.951866) /  24.951866

# every $1 invested in this stock has lost $0.0095 during this one day.
# we can divide the adj close today by price_yesterday, which gives the today worth of $1 invested in this stock
# yesterday as shown below.
# Out:
# -0.009512715401725824

# %%
24.714506 /  24.951866

# this gives us the today's worth of $1 invested in this stock yersterday.
# subtracting 1 from this would give the following.
# Out:
# 0.9904872845982742

# %%
0.9904872845982742 - 1

# this gives the amount lost by investing $1 in this stock as above.
# so, (current price - previous price) / previous price gives us the net gain/loss per $ of investment. In this
# example, it gives us -0.00951, which can be converted to percentage by multiplying it with 100 which then gives
# -0.951%, thus, every $100 invested lost $0.95. Alternatively, we can divide current price by previous price
# (current price / previous price) which gives us the current worth of $1 invested. In this case it is 0.9904 and
# it means that $1 invested in this stock worths $0.9904 today. This can be converted to percentage by multiplying
# with 100 which gives 99.04% which means $100 invested in this stock worths $99.04 today. When 1 subtracted from
# 0.9904, it gives -0.0095 which is the same figure that we earleir obtained by (current price - previous price) / 
# previous price.
# Out:
# -0.009512715401725824

# %%
data['change'] = data['Adj Close'] / data['price_yesterday']

# it gives the today worth of $1 dollar invested yesterday since they are based on daily adj close prices.

# %%
data.head()
# Out:
#              Volume   Adj Close  SMA20  SMA120  price_yesterday     change
# Date
# 2014-12-31  5262600  22.5705376    NaN     NaN              NaN        NaN
# 2015-01-02  3358500  23.4288826    NaN     NaN       22.5705376  1.0380294
# 2015-01-05  5029600  23.9751015    NaN     NaN       23.4288826  1.0233139
# 2015-01-06  9797800  23.9263325    NaN     NaN       23.9751015  0.9979658
# 2015-01-07  9084400  24.1994400    NaN     NaN       23.9263325  1.0114145

# %%
data['invested_SMA'] = np.where(data['SMA20'] > data['SMA120'], 1, 0)
data.head()
# Out:
#              Volume   Adj Close  SMA20  SMA120  price_yesterday     change  \
# Date
# 2014-12-31  5262600  22.5705376    NaN     NaN              NaN        NaN
# 2015-01-02  3358500  23.4288826    NaN     NaN       22.5705376  1.0380294
# 2015-01-05  5029600  23.9751015    NaN     NaN       23.4288826  1.0233139
# 2015-01-06  9797800  23.9263325    NaN     NaN       23.9751015  0.9979658
# 2015-01-07  9084400  24.1994400    NaN     NaN       23.9263325  1.0114145
#
#             invested_SMA
# Date
# 2014-12-31             0
# 2015-01-02             0
# 2015-01-05             0
# 2015-01-06             0
# 2015-01-07             0

# %%
data['invested_SMA'].describe
# Out:
# <bound method NDFrame.describe of Date
# 2014-12-31    0
# 2015-01-02    0
# 2015-01-05    0
# 2015-01-06    0
# 2015-01-07    0
#              ..
# 2020-08-31    1
# 2020-09-01    1
# 2020-09-02    1
# 2020-09-03    1
# 2020-09-04    1
# Name: invested_SMA, Length: 1431, dtype: int64>

# %%
data['invested_SMA'] == 1
# Out:
# Date
# 2014-12-31    False
# 2015-01-02    False
# 2015-01-05    False
# 2015-01-06    False
# 2015-01-07    False
#               ...
# 2020-08-31     True
# 2020-09-01     True
# 2020-09-02     True
# 2020-09-03     True
# 2020-09-04     True
# Name: invested_SMA, Length: 1431, dtype: bool

# %%
data[data['invested_SMA'] == 1]

# Will produce only that part of the data frame where invested_SMA is equal to 1.
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2015-06-23   6173100  33.7387619  34.5166351  29.5384041       33.7387619
# 2015-06-24   4968300  33.9240837  34.5424829  29.6330170       33.7387619
# 2015-06-25   5549700  33.1827888  34.5424829  29.7142995       33.9240837
# 2015-06-26  10686000  32.6316948  34.5315100  29.7864378       33.1827888
# 2015-06-29   9346500  31.7001953  34.4212910  29.8512200       32.6316948
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
#                change  invested_SMA
# Date
# ...

# %%
sma = data[data['invested_SMA'] == 1]
sma
# create a new data frame, sma, containing only those rows invested_SMA is equal to 1. It shows only those rows
# where we have invested based on the strategy when SMA20 was greater than SMA120.
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2015-06-23   6173100  33.7387619  34.5166351  29.5384041       33.7387619
# 2015-06-24   4968300  33.9240837  34.5424829  29.6330170       33.7387619
# 2015-06-25   5549700  33.1827888  34.5424829  29.7142995       33.9240837
# 2015-06-26  10686000  32.6316948  34.5315100  29.7864378       33.1827888
# 2015-06-29   9346500  31.7001953  34.4212910  29.8512200       32.6316948
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
#                change  invested_SMA
# Date
# ...

# %%
# Buy and hold strategy:

# %%
data['buy_and_hold'] = np.cumprod(data['change'])
data

# $1 invested would have grown to $4.8 at the end of the period. This strategy just says to buy at the start of the
# period and holds till end of the period without  basing buy decisions on SMA20 being greater than SMA120. This
# strategy certainly has worked better than buying when SMA20 is greater than SMA120.
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2014-12-31   5262600  22.5705376         NaN         NaN              NaN
# 2015-01-02   3358500  23.4288826         NaN         NaN       22.5705376
# 2015-01-05   5029600  23.9751015         NaN         NaN       23.4288826
# 2015-01-06   9797800  23.9263325         NaN         NaN       23.9751015
# 2015-01-07   9084400  24.1994400         NaN         NaN       23.9263325
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
#                change  invested_SMA  buy_and_hold
# Date
# ...

# %%
# Computation of np.cumproduct:
0.990487 * 0.971829
# Out:
# 0.962583990723

# %%
0.962583990723 * 1.000094
# Out:
# 0.9626744736181281

# %%
0.9626744736181281 * 1.014022

# so, first day 'change' is multiplied with the second day 'change' to get the second day cumulative product. Then
# this second day cumulative product is multiplied with the third day 'change' to get the third day cumulative 
# product. The last day cumulative product at the end of period shows the last day worth of $1 invested on the 
# first day of the period.
# Out:
# 0.9761730950872014

# %%
data
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2014-12-31   5262600  22.5705376         NaN         NaN              NaN
# 2015-01-02   3358500  23.4288826         NaN         NaN       22.5705376
# 2015-01-05   5029600  23.9751015         NaN         NaN       23.4288826
# 2015-01-06   9797800  23.9263325         NaN         NaN       23.9751015
# 2015-01-07   9084400  24.1994400         NaN         NaN       23.9263325
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
#                change  invested_SMA  buy_and_hold
# Date
# ...

# %%
119.859116 / 24.951864 

# its the same as the last value in the buy and hold column and in both cases it can be interpreted as: $1 invested
# would have grown to $ 4.8 at the end of the period.
# Out:
# 4.8036137099817475

# %%
data.head()
# Out:
#              Volume   Adj Close  SMA20  SMA120  price_yesterday     change  \
# Date
# 2014-12-31  5262600  22.5705376    NaN     NaN              NaN        NaN
# 2015-01-02  3358500  23.4288826    NaN     NaN       22.5705376  1.0380294
# 2015-01-05  5029600  23.9751015    NaN     NaN       23.4288826  1.0233139
# 2015-01-06  9797800  23.9263325    NaN     NaN       23.9751015  0.9979658
# 2015-01-07  9084400  24.1994400    NaN     NaN       23.9263325  1.0114145
#
#             invested_SMA  buy_and_hold
# Date
# 2014-12-31             0           NaN
# 2015-01-02             0     1.0380294
# 2015-01-05             0     1.0622300
# 2015-01-06             0     1.0600692
# 2015-01-07             0     1.0721694

# %%
sma
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2015-06-23   6173100  33.7387619  34.5166351  29.5384041       33.7387619
# 2015-06-24   4968300  33.9240837  34.5424829  29.6330170       33.7387619
# 2015-06-25   5549700  33.1827888  34.5424829  29.7142995       33.9240837
# 2015-06-26  10686000  32.6316948  34.5315100  29.7864378       33.1827888
# 2015-06-29   9346500  31.7001953  34.4212910  29.8512200       32.6316948
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
#                change  invested_SMA
# Date
# ...

# %%
sma['return'] = np.cumprod(sma['change'])
sma

# following this strategy of buying when SMA20 is greater than SMA120 would result in this return which can be 
# interpreted as: $1 investment would have grown to $2.91 dollars at the end of the period using this strategy.
# Out:
# /tmp/ipykernel_17510/965371665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sma['return'] = np.cumprod(sma['change'])
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2015-06-23   6173100  33.7387619  34.5166351  29.5384041       33.7387619
# 2015-06-24   4968300  33.9240837  34.5424829  29.6330170       33.7387619
# 2015-06-25   5549700  33.1827888  34.5424829  29.7142995       33.9240837
# 2015-06-26  10686000  32.6316948  34.5315100  29.7864378       33.1827888
# 2015-06-29   9346500  31.7001953  34.4212910  29.8512200       32.6316948
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# ...

# %%
data.loc['2015, 06, 23': '2015-06-29']
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2015-06-23   6173100  33.7387619  34.5166351  29.5384041       33.7387619
# 2015-06-24   4968300  33.9240837  34.5424829  29.6330170       33.7387619
# 2015-06-25   5549700  33.1827888  34.5424829  29.7142995       33.9240837
# 2015-06-26  10686000  32.6316948  34.5315100  29.7864378       33.1827888
# 2015-06-29   9346500  31.7001953  34.4212910  29.8512200       32.6316948
#
#                change  invested_SMA  buy_and_hold
# Date
# 2015-06-23  1.0000000             1     1.4948143
# 2015-06-24  1.0054928             1     1.5030251
# 2015-06-25  0.9781484             1     1.4701816
# 2015-06-26  0.9833922             1     1.4457651
# 2015-06-29  0.9714541             1     1.4044945

# %%
data
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2014-12-31   5262600  22.5705376         NaN         NaN              NaN
# 2015-01-02   3358500  23.4288826         NaN         NaN       22.5705376
# 2015-01-05   5029600  23.9751015         NaN         NaN       23.4288826
# 2015-01-06   9797800  23.9263325         NaN         NaN       23.9751015
# 2015-01-07   9084400  24.1994400         NaN         NaN       23.9263325
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
#                change  invested_SMA  buy_and_hold
# Date
# ...

# %%
plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid((10, 1), (0, 0), rowspan = 4, colspan = 1, title = ticker)
ax2 = plt.subplot2grid((10, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)
ax3 = plt.subplot2grid((10, 1), (8, 0), rowspan = 2, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price', alpha = 0.75)
ax1.plot(data['SMA20'], label = 'SMA20')
ax1.plot(data['SMA120'], label = 'SMA120')

ax2.bar(data.index, data['Volume'], label = 'Volume')

ax3.plot(data['buy_and_hold'], label = 'Buy and Hold')
ax3.plot(sma['return'], label = 'SMA')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y, %m'))

ax3.set_xlabel('Date (Year - Month)')

ax1.legend()
ax2.legend(loc = 'upper right')
ax3.legend()

# Hold and Buy strategy has outperformed the strategy based on buying when SMA20 is greater than SMA120.

# %% [markdown]
# #### Exponential weighted moving average strategy:

# %%
data['EWM12'] = data['Adj Close'].ewm(span =12, adjust = False).mean()
data['EWM26'] = data['Adj Close'].ewm(span =26, adjust = False).mean()

# More weight is assigned in weighted moving average such as EWM based on timing or frequency. For instance, more
# recent prices could be assigned more weight as compared to relatively old prices.

# %%
data
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2014-12-31   5262600  22.5705376         NaN         NaN              NaN
# 2015-01-02   3358500  23.4288826         NaN         NaN       22.5705376
# 2015-01-05   5029600  23.9751015         NaN         NaN       23.4288826
# 2015-01-06   9797800  23.9263325         NaN         NaN       23.9751015
# 2015-01-07   9084400  24.1994400         NaN         NaN       23.9263325
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
#                change  invested_SMA  buy_and_hold       EWM12       EWM26
# ...

# %%
data['invested_EWM'] = np.where(data['EWM12'] > data['EWM26'], 1, 0)
data
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2014-12-31   5262600  22.5705376         NaN         NaN              NaN
# 2015-01-02   3358500  23.4288826         NaN         NaN       22.5705376
# 2015-01-05   5029600  23.9751015         NaN         NaN       23.4288826
# 2015-01-06   9797800  23.9263325         NaN         NaN       23.9751015
# 2015-01-07   9084400  24.1994400         NaN         NaN       23.9263325
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
# ...

# %%
ewm = data[data['invested_EWM'] == 1]
ewm
# Out:
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2015-01-02   3358500  23.4288826         NaN         NaN       22.5705376
# 2015-01-05   5029600  23.9751015         NaN         NaN       23.4288826
# 2015-01-06   9797800  23.9263325         NaN         NaN       23.9751015
# 2015-01-07   9084400  24.1994400         NaN         NaN       23.9263325
# 2015-01-08  12821700  24.4627972         NaN         NaN       24.1994400
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# 2020-09-01  11431400  80.4599686  69.1239822  53.8381481       76.7047195
# 2020-09-02  13860900  81.1622543  69.9867155  54.1917272       80.4599686
# 2020-09-03  19254000  77.0948715  70.6758287  54.5477447       81.1622543
# 2020-09-04  21500900  78.0312500  71.5507542  54.8862866       77.0948715
#
# ...

# %%
ewm['return'] = np.cumprod(ewm['change'])
ewm
# Out:
# /tmp/ipykernel_17510/1146488008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ewm['return'] = np.cumprod(ewm['change'])
#               Volume   Adj Close       SMA20      SMA120  price_yesterday  \
# Date
# 2015-01-02   3358500  23.4288826         NaN         NaN       22.5705376
# 2015-01-05   5029600  23.9751015         NaN         NaN       23.4288826
# 2015-01-06   9797800  23.9263325         NaN         NaN       23.9751015
# 2015-01-07   9084400  24.1994400         NaN         NaN       23.9263325
# 2015-01-08  12821700  24.4627972         NaN         NaN       24.1994400
# ...              ...         ...         ...         ...              ...
# 2020-08-31  12917300  76.7047195  68.2500324  53.4786354       77.9922333
# ...

# %%
#%matplotlib notebook
plt.figure(figsize=(14, 10))

ax1 = plt.subplot2grid((10, 1), (0, 0), rowspan = 4, colspan = 1, title = ticker)
ax2 = plt.subplot2grid((10, 1), (5, 0), rowspan = 2, colspan = 1, sharex = ax1)
ax3 = plt.subplot2grid((10, 1), (8, 0), rowspan = 3, colspan = 1, sharex = ax1)

ax1.plot(data['Adj Close'], label = 'Price')
ax1.plot(data['SMA20'], label = 'SMA20')
ax1.plot(data['SMA120'], label = 'SMA120')
ax1.plot(data['EWM12'], label = 'EWM12')
ax1.plot(data['EWM26'], label = 'EWM26')

ax2.bar(data.index, data['Volume'], label = 'Volume')

ax3.plot(data['buy_and_hold'], label = 'Buy and Hold')
ax3.plot(sma['return'], label = 'SMA')
ax3.plot(ewm['return'], label = 'EWM')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y, %m'))

ax3.set_xlabel('Date (Year - Month)')

ax1.legend(fontsize = 10)
ax2.legend(fontsize = 10, loc = 'upper right')
ax3.legend(fontsize = 8)
plt.savefig('ewm.png')
plt.show()

# from the first graph, we can compare EWM12 with EWM26. When the EWM12 goves above EWM26, it is a buy signal and
# we buy. Similarly, we EWM12 goves below EWM26, it is a sell signal and we sell. Based on EWM strategy of buy and
# sell, we generate the return graphed in the last graph, which shows that a higher return has been generated 
# following EWM strategy as compared to SMA and Buy and Hold strategies.

# EWM strategy generates more timely signals to buy and sell as compared to SMA strategy. Therefore, it generates
# superior returns.

# %%
# pip install ipywidgets

# %%
# jupyter nbextension enable --py widgetsnbextension

# %% [markdown]
# #### Multiple stocks (assets):

# %%
tickers = ['FB', 'CVNA', 'JD', 'ADBE', 'TWTR']

# %%
for ticker in tickers:
    data = web.DataReader(ticker, 'yahoo', start, end)
    data = data.drop(columns = ['High', 'Low', 'Open', 'Close'])
    data['SMA20'] = data['Adj Close'].rolling(20).mean()
    data['SMA120'] = data['Adj Close'].rolling(120).mean()
    data['EWM12'] = data['Adj Close'].ewm(span = 12, adjust = False).mean()
    data['EWM26'] = data['Adj Close'].ewm(span = 26, adjust = False).mean()
    data['price_yesterday'] = data['Adj Close'].shift(1)
    data['change'] = data['Adj Close'] / data['price_yesterday']
    data['invested_SMA'] = np.where(data['SMA20'] > data['SMA120'], 1, 0)
    data['invested_EWM'] = np.where(data['EWM12'] > data['EWM26'], 1, 0)
    sma = data[data['invested_SMA'] == 1] # only take those rows from dataframe, sma, where the condition is satis-
     # fied and store them in new dataframe, sma. The condition is: data['invested_SMA'] == 1.
    ewm = data[data['invested_EWM'] == 1]
    data['buy_and_hold'] = np.cumprod(data['change'])
    sma['return'] = np.cumprod(sma['change']) # sma['change'] is the same column as data['change'] except that
    # data['change'] has all the values whereas sma['change'] has only the values where the condition was met.
    ewm['return'] = np.cumprod(ewm['change'])
    print(ticker)
    print('Buy and Hold return: ' + str(data['buy_and_hold'][-1])) # two strings concatenated.
    print('SMA return: ' + str(sma['return'][-1]))
    print('EWM return: ' + str(ewm['return'][-1]))
# Out:
# /tmp/ipykernel_17510/1445539800.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sma['return'] = np.cumprod(sma['change']) # sma['change'] is the same column as data['change'] except that
# /tmp/ipykernel_17510/1445539800.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ewm['return'] = np.cumprod(ewm['change'])
# FB
# Buy and Hold return: 3.6238147032970276
# SMA return: 2.111415320596423
# EWM return: 4.205731203460684
# CVNA
# Buy and Hold return: 16.846846267877332
# ...

# %% [markdown]
# ### Conclusion:
# ##### No strategy gurantees favorable outcome. No strategy is all the time winner for all the firms.
# ##### Finance is not a physical science. Many factors are at play at once.
# ##### A company crashed in 2020 thought all the charts generating buy signals for it.
# ##### Buy and sell signals based on moving averages will depend on your belief in momentum vs contrarian strategy.
# ##### The moving average is just one of the many techniques of technical analysis (chartists). The other techniques are candlesticks, relative strength etc.
# ##### Fundamental analysis is another stream of analysis, where undervalued stocks are searched rather than making decisions entirely on the basis of trends shown in charts and graphs. This is the topic of our next section in this course.

# %%
data['buy_and_hold'][-1] # the last value in 'buy_and_hold' column in the data frame, data, which is 10.61 for AMZN which 
# means $1 invested at the start of the period would have grown to $ 4.8 at the end of period using buy and hold
# strategy.
# Out:
# 1.111513803153318

# %%
data['buy_and_hold']
# Out:
# Date
# 2014-12-31          NaN
# 2015-01-02    1.0192362
# 2015-01-05    1.0142181
# 2015-01-06    1.0805687
# 2015-01-07    1.0393086
#                 ...
# 2020-08-31    1.1313076
# 2020-09-01    1.1471983
# 2020-09-02    1.2174519
# 2020-09-03    1.1605799
# 2020-09-04    1.1115138
# Name: buy_and_hold, Length: 1431, dtype: float64

# %%
sma['return'][-1] # interpret same as above expcept that this is SMA strategy.
# Out:
# 1.036797919510245

# %%
ewm['return'][-1] # interpret same as above expcept that this is SMA strategy.
# Out:
# 4.900154481111241

# %%
type(ewm['return']) # [-1] can be applied to obtain the last value from the series as done above.
# Out:
# pandas.core.series.Series

# %%
data # just to see the data for various reasons when working at different things.
# Out:
#               Volume   Adj Close       SMA20      SMA120       EWM12  \
# Date
# 2014-12-31  17629400  35.8699989         NaN         NaN  35.8699989
# 2015-01-02  12062500  36.5600014         NaN         NaN  35.9761532
# 2015-01-05  15062700  36.3800011         NaN         NaN  36.0382836
# 2015-01-06  33050800  38.7599983         NaN         NaN  36.4570089
# 2015-01-07  22675700  37.2799988         NaN         NaN  36.5836228
# ...              ...         ...         ...         ...         ...
# 2020-08-31   7468300  40.5800018  38.6549997  32.0092500  39.7461163
# 2020-09-01  10468000  41.1500015  38.8949999  32.1290000  39.9620987
# 2020-09-02  26800000  43.6699982  39.2389997  32.2488333  40.5325447
# 2020-09-03  18760800  41.6300011  39.4359999  32.3954166  40.7013842
# 2020-09-04  17825000  39.8699989  39.5724998  32.5236666  40.5734788
#
#                  EWM26  price_yesterday     change  invested_SMA  \
# Date
# ...
